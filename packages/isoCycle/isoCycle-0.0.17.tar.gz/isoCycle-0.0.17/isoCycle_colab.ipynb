# %% [markdown]
# <a href="https://colab.research.google.com/github/esiabri/isoCycle/blob/main/isoCycle_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# # installing the isoCycle from PyPI
# pip install isocycle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 21.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for isocycle: filename=isoCycle-0.0.13-py3-none-any.whl size=15796205 sha256=1c6c5ff83bcc601d91ef2c634c50a71443dc9a7bbb75af95722a0a7272354dcc
#   Stored in directory: /root/.cache/pip/wheels/3b/06/e2/ec9aa5359f528665e3b8d16edc569cedad5d586bf354fd09b7
# Successfully built isocycle
# ...

# %%
import pickle

from isoCycle.decoder import cycleDetection

# %%
spikeTimes_fileAdd = '/content/drive/MyDrive/isoCycle/spikeTimes.pkl'  # replace the address to your file

with open(spikeTimes_fileAdd,'rb') as f:
        spikesTimes = pickle.load(f)

# %%
# if you want to just check the data, pick a shorter duration than the whole data length
# as it might takes long to run dependeing on your processor/gpu and the recording length 
# (e.g. 17 mins to find 29 k gamma cycles during 6300 seconds of a recording with 2.8 mil spikes, on RTX 2070)

# suggested length for gamma for testing
dataLengthToSearch = 10 # seconds

# if you want to run on the whole session, change the "wholeSession" variable to "True"
wholeSession = False

detectedCyclesTimes_gamma = cycleDetection(spikesTimes, cycleName='gamma', wholeSession=wholeSession,\
                                           cycleDetectionDur=dataLengthToSearch,\
                                           decoderAdd='/content/drive/MyDrive/isoCycle/isoCycle_publishedModel_2022-06-28.pkl')
# Out:
# 402/402 [==============================] - 47s 114ms/step
# 509 gamma cycles detected during 10 seconds in V1

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
from google.colab import output
output.disable_custom_widget_manager()
